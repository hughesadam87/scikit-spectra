# %%
# %run NBCONFIG.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# /* Width of all cells */
# ...

# %%
from pyuvvis.data import aunps_water

ts = aunps_water()
ts.as_interval('s').plot(cbar=True);
# Out:
# WARNING:pyuvvis.core.timespectra:SpecIndex unit was changed internally from "None" to "nm"

# %%
ts.baseline = 305.
ts.sub_base()
ts=ts.ix[350:700]
stack = ts.sample_by(4, keys=['lol', 'hax', 'base','foo'])
stack.reference=0
stack.iunit = 'a'
stack.plot(ncols=2, figsize=(8,8), color='bone');
# Out:
# CRITICAL:pyuvvis.core.timespectra:Subtracting baseline, but may not have all: elements being equal.  Fix index
# WARNING:pyuvvis.core.utilities:Returning uneven sampling for (n=4) along axis 1of size 78

# %%
from pyuvvis.plotting import quad_plot

fig = quad_plot(ts, color='bone', striplegend=True)
